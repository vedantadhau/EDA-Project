# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('diamonds.csv')

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data1=data.head(15)

# %%
data1
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    15 non-null     float64
#  1   cut      15 non-null     object
#  2   color    15 non-null     object
#  3   clarity  15 non-null     object
#  4   depth    15 non-null     float64
#  5   table    15 non-null     float64
#  6   price    15 non-null     int64
#  7   x        15 non-null     float64
#  8   y        15 non-null     float64
#  9   z        15 non-null     float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
plt.plot(data1.price)
plt.grid(True)
plt.ylabel('Prices')
# Out:
# Text(0, 0.5, 'Prices')

# %%
plt.pie(data1.depth,labels=data1.depth)
# Out:
# ([<matplotlib.patches.Wedge at 0x16e0e072c40>,
# ...
#  [Text(1.0760916471494109, 0.22809376785714228, '61.5'),
#   Text(0.8947248804098784, 0.6398963887814408, '59.8'),
#   Text(0.57832786473638, 0.9357012775824662, '56.9'),
#   Text(0.16266227960880963, 1.0879066976503389, '62.4'),
#   Text(-0.3024028511341237, 1.0576164312386382, '63.3'),
#   Text(-0.7143217260064504, 0.8365073052610873, '62.8'),
#   Text(-0.9956275988346007, 0.4676811781960521, '62.3'),
#   Text(-1.0998349876772355, 0.01905255576071993, '61.9'),
#   Text(-1.0070661884458643, -0.4425129287253869, '65.1'),
#   Text(-0.7367839112393703, -0.8167921817321808, '59.4'),
#   Text(-0.34062950786974766, -1.0459309434032504, '64.0'),
#   Text(0.12711090838134842, -1.0926311440602765, '62.8'),
#   Text(0.5601060505948258, -0.9467212958875841, '60.4'),
#   Text(0.8951591218531988, -0.6392887818216508, '62.2'),
#   Text(1.0770881624984951, -0.223340749093432, '60.2')])

# %%
plt.violinplot(data1.price)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x16e0dfcdd60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x16e0dfcdeb0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x16e0dfb51c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x16e0dfb5970>}

# %%
plt.hist(data1.price)
# Out:
# (array([3., 0., 0., 0., 2., 4., 2., 1., 1., 2.]),
#  array([326. , 327.9, 329.8, 331.7, 333.6, 335.5, 337.4, 339.3, 341.2,
#         343.1, 345. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(data1.price,data1.depth)
# Out:
# <BarContainer object of 15 artists>

# %%
sns.boxplot(data1.table,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='table', ylabel='depth'>

# %%
sns.violinplot(data1.table,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='table', ylabel='depth'>

# %%
sns.pointplot(data1.table,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='table', ylabel='depth'>

# %%
sns.lineplot(data1.table,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='table', ylabel='depth'>

# %%
sns.countplot(data1.cut)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
sns.scatterplot(data1.table,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='table', ylabel='depth'>

# %%
sns.scatterplot(data1.price,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='depth'>

# %%
sns.regplot(data1.table,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='table', ylabel='depth'>

# %%
sns.regplot(data1.price,data1.depth)
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='depth'>

# %%
sns.lmplot(x='price',y='depth',data=data1,order=4)

# %%
sns.heatmap(data1[['price','depth']])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data1[['table','depth']])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data1[['table','depth']])
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(data1)
